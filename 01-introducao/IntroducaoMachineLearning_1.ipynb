# %%
import pandas as pd
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error

# %%
df = pd.read_csv('USA_Housing.csv')

# %%
df.head()
# Out:
#    Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0      79545.458574             5.682861                   7.009188
# 1      79248.642455             6.002900                   6.730821
# 2      61287.067179             5.865890                   8.512727
# 3      63345.240046             7.188236                   5.586729
# 4      59982.197226             5.040555                   7.839388
#
#    Avg. Area Number of Bedrooms  Area Population         Price  \
# 0                          4.09     23086.800503  1.059034e+06
# 1                          3.09     40173.072174  1.505891e+06
# 2                          5.13     36882.159400  1.058988e+06
# 3                          3.26     34310.242831  1.260617e+06
# 4                          4.23     26354.109472  6.309435e+05
#
#                                              Address
# 0  208 Michael Ferry Apt. 674\nLaurabury, NE 3701...
# 1  188 Johnson Views Suite 079\nLake Kathleen, CA...
# ...

# %%
## Eliminar coluna Adress pare calcular a correlação (Todos os dados precisam ser númericos)
df_sem_endereco = df.drop(columns=['Address'])
df_sem_endereco.corr()
# Out:
#                               Avg. Area Income  Avg. Area House Age  \
# Avg. Area Income                      1.000000            -0.002007
# Avg. Area House Age                  -0.002007             1.000000
# Avg. Area Number of Rooms            -0.011032            -0.009428
# Avg. Area Number of Bedrooms          0.019788             0.006149
# Area Population                      -0.016234            -0.018743
# Price                                 0.639734             0.452543
#
#                               Avg. Area Number of Rooms  \
# Avg. Area Income                              -0.011032
# Avg. Area House Age                           -0.009428
# Avg. Area Number of Rooms                      1.000000
# Avg. Area Number of Bedrooms                   0.462695
# Area Population                                0.002040
# Price                                          0.335664
#
#                               Avg. Area Number of Bedrooms  Area Population  \
# ...

# %%
x = df[['Avg. Area Income', 'Avg. Area House Age', 'Avg. Area Number of Rooms', 'Area Population']] ##Características
y = df['Price'] ##Alvo
## Coluna 'Avg. Area Number of Bedrooms' não foi seleccionada para nossa análise por apresentar baixa correlação com 'Price'

# %%
x_treino, x_teste, y_treino, y_teste = train_test_split(x,y)

# %%
## Modelagem
modelo = LinearRegression() ## Criar um objeto

# %%
modelo.fit(x_treino, y_treino) ## Vai aprender
# Out:
# LinearRegression()

# %%
y_previsto = modelo.predict(x_teste)

# %%
y_previsto
# Out:
# array([1333401.10163116, 1440474.50664917,  732951.84043268, ...,
#        1080141.82826193, 1213076.53375775, 1252692.72227502])

# %%
## Preço médio de uma casa nos Estados Unidos segundo dados do nosso dataset
df['Price'].mean()
# Out:
# 1232072.654142357

# %%
## - Avaliação do nosso modelo, mostra o quanto errou na média
## - Esse resultado é uma diferença grande de 80 mil no preço final (pra mais ou pra menos), portanto o próximo passo 
## seria fazer outras técnicas e manipulações
mean_absolute_error(y_previsto, y_teste)
# Out:
# 82295.49071692403
